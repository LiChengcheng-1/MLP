# %%
import pandas
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

# %%
df = pandas.read_csv('E:\lesson\MLP\MLP_Test Task\data\Flow Estimation Data/Fluid2.csv')
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2843 entries, 0 to 2842
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Level Sensor-1  2843 non-null   float64
#  1   Level Sensor-2  2843 non-null   float64
#  2   Level Sensor-3  2843 non-null   float64
#  3    Fluid Flow     2843 non-null   float64
# dtypes: float64(4)
# memory usage: 89.0 KB
#        Level Sensor-1  Level Sensor-2  Level Sensor-3   Fluid Flow
# count     2843.000000     2843.000000     2843.000000  2843.000000
# mean        77.965542       76.985999       49.914919   425.266563
# std          6.922775        6.928232        5.047144    83.363650
# min         57.118368       58.525260       28.431188   279.113382
# 25%         72.987301       71.912927       46.330045   353.861459
# 50%         78.521202       77.534033       50.186557   432.225123
# 75%         83.836727       82.571158       53.764564   489.428796
# ...

# %%
#checking the missing value
missing = df.columns[df.isnull().any() ].tolist()
df[missing].isnull().sum()
# Out:
# Series([], dtype: float64)

# %%
# check if linear correleration
num_cols=[
"Level Sensor-1","Level Sensor-2","Level Sensor-3"]
for col in num_cols:
    warnings.filterwarnings("ignore")
    sns.pairplot(df[[col]+[' Fluid Flow']])

# %%
#draw the heat map
correlation =df.corr()
fig = plt.figure(figsize=(10,10))
sns.heatmap(correlation,annot = True,linewidths=1)
plt.show()
