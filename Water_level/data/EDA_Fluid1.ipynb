# %%
import pandas
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

# %%
df = pandas.read_csv('E:\lesson\MLP\MLP_Test Task\data\Flow Estimation Data/Fluid1.csv')
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4985 entries, 0 to 4984
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Level Sensor-1  4985 non-null   float64
#  1   Level Sensor-2  4985 non-null   float64
#  2   Level Sensor-3  4985 non-null   float64
#  3    Fluid Flow     4985 non-null   float64
# dtypes: float64(4)
# memory usage: 155.9 KB
#        Level Sensor-1  Level Sensor-2  Level Sensor-3   Fluid Flow
# count     4985.000000     4985.000000     4985.000000  4985.000000
# mean        85.174426       84.161592       52.353301   376.152630
# std         11.110536       10.873734        7.943132    80.044925
# min         59.902743       55.623140       25.462888   252.008110
# 25%         75.275471       74.288800       45.539424   305.642992
# 50%         85.467742       84.436764       52.283630   370.325103
# 75%         94.320219       93.286131       58.657243   443.662629
# max        106.892068      105.497836       70.881695   536.216304

# %%
#checking the missing value
missing = df.columns[df.isnull().any() ].tolist()
df[missing].isnull().sum()
# Out:
# Series([], dtype: float64)

# %%
# check if linear correleration
num_cols=[
"Level Sensor-1","Level Sensor-2","Level Sensor-3"]
for col in num_cols:
    warnings.filterwarnings("ignore")
    sns.pairplot(df[[col]+[' Fluid Flow']])

# %%
#draw the heat map
correlation =df.corr()
fig = plt.figure(figsize=(10,10))
sns.heatmap(correlation,annot = True,linewidths=1)
plt.show()
